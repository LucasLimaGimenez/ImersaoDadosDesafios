# %% [markdown]
# #IMERSÃO DADOS

# %% [markdown]
# #Criação do import pandas que será utilizado para analisar esse documento

# %%
import pandas as pd #utilizar a biblioteca de análise de dados

#url que serve para pegar o documento a ser analisado
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression = "zip") #momento em que acontece a leitura do documento csv
display(dados) #mostra a tabela para nossa visualização
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# #Códigos comentados

# %%
#serve para pegar as apenas as 5 linhas iniciais da tabela
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#serve para saber o tamanho de linhas e colunas
dados.shape
# Out:
# (23814, 877)

# %%
dados["tratamento"].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados["tratamento"].unique() #mostra as categorias/valores unicos da coluna
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados["tempo"].unique() #mostra os valores que aparecem nesse caso as horas usadas para cada tratamento
# Out:
# array([24, 72, 48])

# %%
dados["dose"].unique() #mostra as categorias que aparecem dentro da coluna dose
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados["droga"].unique() #mostra todos os tipos de droga existente na tabela nesse caso os dados estão criptografados
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
 dados["g-0"].unique() #valores utilizados na coluna g-0
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados["tratamento"].value_counts() #mostra a quantidade de vezes que aparece cada valor
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts(normalize = True) #mostra o valor com 0, a esquerda
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
mapa = {'droga': 'composto'} #responsavel por armazenar o novo nome da coluna
dados.rename(columns = mapa, inplace=True) #realiza a alteração do nome completamente

# %%
dados.head() #5primeiros valores da tabela
dados['composto'].value_counts().head() #pega os 5 valores que mais aparecem na coluna composto
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %% [markdown]
# #Inicio Formação de tabelas

# %%
dados["tratamento"].value_counts().plot.pie() #gera uma tabela em formato de pizza com os dados tratamento

# %%
dados["tempo"].value_counts().plot.pie() #gera uma tabela de formato de pizza com os dados do tempo

# %%
dados["tempo"].value_counts().plot.bar() #gera uma tabela em formato de barras com os dados do tempo

# %%
dados_filtrados = dados[dados["g-0"] > 0 ] #mostra apenas os valores de g-0 que possuem valor maior que 0
dados_filtrados.head() #mostra os 5 primeiros valores g-0 que são maiores que 0.
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5] #pega os 5 valores que mais aparecem na coluna composto

# %%
cod_compostos #executa variavel
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
 dados.query('composto in @cod_compostos') #todos os cod_composto que estiver igual dentro da tabela composto
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# #Criação de tabela estilizada usando Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
#plt.title("Gráfico de barras") pode ser feito assim o titulo
ax = sns.countplot(x ='composto',data=dados.query('composto in @cod_compostos')) #gera uma tabela de barras com cores diferentes para cada barra
ax.set_title("Top 5 Compostos") #pode ser feito assim o titulo
plt.show()

# %% [markdown]
# #Códigos comentados que ajudarão na criação dos histogramas

# %%
len(dados['g-0'].unique()) #mostra a quantidade de valores unicos na coluna
# Out:
# 14367

# %%
dados["g-0"].max() #mostra o valor máximo da coluna
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100) #mostra um grafico no estilo histografico

# %%
dados['g-19'].hist(bins = 100)

# %%
dados['tratamento'].hist() #pode ser usada para graficos com menos valores unicos

# %%
maior1 = len(dados[dados['g-0']> 1]) #utilizando length para pegar a quantidade de valores que são unicos e maiores que 1
maior1
# Out:
# 3267

# %% [markdown]
# #Código describe

# %%
dados.describe() #mostra uma descrição com valores da tabela
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados["g-0"].describe() #pode ser utilizado para pegar valores estatísticos
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g-0, dtype: float64

# %% [markdown]
# #Código Loc

# %%
dados.loc[0,'g-0'] #mostra o valor do elemento da linha 0 coluna g-0
# Out:
# 1.062

# %%
dados.loc[0:,'g-0'] #pega do primeiro ao ultimo elemento da coluna
# Out:
# 0        1.0620
# 1        0.0743
# 2        0.6280
# 3       -0.5138
# 4       -0.3254
#           ...
# 23809    0.1394
# 23810   -1.3260
# 23811    0.3942
# 23812    0.6660
# 23813   -0.8598
# Name: g-0, Length: 23814, dtype: float64

# %%
dados.loc[:,'g-0':'g-771'].describe() #mostra a descrição de todos os g
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe().T #transforma as colunas em linhas
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %% [markdown]
# #Código loc junto com describe e histograma

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=30)  #criação da tabela juntando os g e a media de cada um

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50) #mesma idéia so que utilizando como base as propriedades c

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30) #grafico mostrando a quantidade dos g em cada valor percebendo a quantidade no valor -10

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30) #grafico mostrando a quantidade dos g em cada valor percebendo a quantidade no valor 10

# %% [markdown]
# #Boxplot

# %%
sns.boxplot(x ='g-0' , data = dados)

# %%
sns.boxplot(x='g-0',y='tratamento',data=dados) #mostra os g que se diferenciam entre com_droga e com controle e a quantidade em q cada um aparece

# %%
plt.figure(figsize=(10,8)) #aumenta o tamanho da tabela
sns.boxplot(y='g-0',x='tratamento',data=dados) #formato vertical

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# #Utilizando Crosstab

# %%
pd.crosstab(dados['dose'],dados['tempo']) #relação de dados criada a partir de duas colunas, ex:3886 doses do tipo d1 são usadas por 24 horas
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento']) #relação de dados criada a partir de três colunas
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize= True) *100  #calcula a proporção de cada célula com soma de todos os valores no final sendo 100%
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         1.263962  15.054170
#      48         1.440329  16.843034
#      72         1.289158  15.117158
# D2   24         1.280759  15.037373
#      48         1.280759  15.079365
#      72         1.280759  15.033174

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize= 'index')   #calcula a proporção de cada célula com soma de todos os valores na linha sendo 100% a cada dose/tempo.
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],values = dados['g-0'], aggfunc= 'mean')  #mostra uma tabela de dados que analisa o g-0 quando recebe uma dose pequena em sua média para cada horário e dose especifica tanto com_controle quanto com_droga
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# #Utilizando scatterplot

# %%
sns.scatterplot(x = 'g-0',y = 'g-3',data = dados) #cada ponto é referente a cada cordenada de dados[['g-0','g-3']]

# %%
dados[['g-0','g-3']] #mostra uma tabela com duas colunas mostrando seus resultados
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0',y='g-8',data = dados) #nesse código é possivel perceber que quanto maior o valor de g-0 menor é o valor de g-8

# %% [markdown]
# #Utilizando lmplot

# %%
sns.lmplot(data = dados,x ='g-0',y='g-8',line_kws={'color':'red'}) #mostra o mesmo gráfico que o de cima entretanto possui uma linha de tendência no gráfico

# %%
sns.lmplot(data = dados,x ='g-0',y='g-8',line_kws={'color':'red'},col='tratamento') #gera uma tabela para cada tipo de tratamento mostrando que quando esta com_controle ela se mantém ja com_droga ela se altera

# %%
sns.lmplot(data = dados,x ='g-0',y='g-8',line_kws={'color':'red'},col='tratamento', row='tempo') #gera uma tabela para cada tipo de tratamento seguindo o tempo de cada tratamento mostrando o g-0 e g-8 dentro deles percebendo que quanto mais tempo mais se equilibra o tratamento com controle ja no com_droga maior é a queda conforme o tempo passa

# %%
dados.loc[:,'g-0':'g-771'].corr() #mostra as correlações que cada valor possui com outro valor g como no caso g-1 para g-1 é 100% enquanto g-1 para g-0 é 8% apenas,mostrando serem inversamente proporcionais
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].corr().head(9) #aqui podemos observar como o g-0 é inversamente proporcional ao g-8 n sendo a causa desse problema mas algo a se analisar

# %% [markdown]
# #Utilizando import numpy

# %%
#gráfico referente aos dados obtidos acima(gráfico de correlação),facilitando a visualização dos dados

import numpy as np

corr = dados.loc[:,'g-0':'g-50'].corr() #correlação

mask = np.triu(np.ones_like(corr,dtype=bool))

#tamanho do gráfico
f,ax = plt.subplots(figsize=(11,9))

cmap = sns.diverging_palette(230,20,as_cmap=True)

#desenha os valores no gráfico
sns.heatmap(corr,mask=mask,cmap = cmap,center= 0,square=True,linewidths=.5,cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr() #c = viabilidade celular para cada tratamento

#o tipo celular está altamente correlacionado entre si como mostra no gráfico

mask = np.triu(np.ones_like(corr_celular,dtype=bool))

#tamanho do gráfico
f,ax = plt.subplots(figsize=(11,9))

cmap = sns.diverging_palette(230,20,as_cmap=True)

#desenha os valores no gráfico
sns.heatmap(corr_celular,mask=mask,cmap = cmap,center= 0,square=True,linewidths=.5,cbar_kws={"shrink": .5})

# %% [markdown]
# #Nova tabela a ser analisada

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true') #nova tabela a ser analisada
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique() #mostra que os valores utilizados são 0 e 1 dentro dessa coluna
# Out:
# array([0, 1])

# %% [markdown]
# ##Pode ser feito de duas formas ->

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False) #seleciona as colunas que possuem apenas valores inteiros e soma os valores existentes nela alinhando do maior para menor
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa2 = dados_resultados.drop('id',axis=1).sum().sort_values(ascending=False) #ignora a coluna selecionada dentro do drop na hora de realizar a função
contagem_moa2
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# ##Pega informações sobre uma variável/array

# %%
dados_resultados.info() #mostra informações sobre o array de valores
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
#dados_resultados.sum().sort_values() #nesse caso gera um erro pois e impossivel fazer comparações de  Strings

# %%
dados_resultados.drop('id',axis=1).sum(axis=1) #mostra quantos mecanismos de ação cada linha ativou/executou
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# ##Mostrando as colunas de cada tabela

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# #Realizando operações com n-moa

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id',axis=1).sum(axis = 1) #mostra quantos mecanismos de ação cada linha ativou/executou e guarda em uma nova coluna
dados_resultados['n_moa'].value_counts() #mostra os tipos existentes e a soma dos valores de cada tipo
# Out:
# 1    12532
# 0     9367
# 2     1538
# 3      303
# 4       55
# 5       13
# 7        6
# Name: n_moa, dtype: int64

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0 ) #cria uma coluna no final da tabela que dirá se possui ou não moas em cada linha
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# #Utilizando o merge

# %%
dados_combinados = pd.merge(dados,dados_resultados[['id','n_moa','ativo_moa']],on='id') #realiza a combinação de duas tabelas com  a chave primária id
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# #Utilizando o query

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts() #mostra que nenhum dos que possuem valor ativo_moa = true existem no tratamento com_controle logo todo tratamento com controle possui ativo_moa = 0(False)
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts() #já nessa análise é possivel perceber que é muito mais frequente o ativo_moa receber valores quando o tratamento é com drogas
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# #Criando um boxplot com o ativo_moa

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5] #pega os 5 compostos que mais aparecem
plt.figure(figsize=(10,8)) #gera o tamanho da tabela
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'),y ='g-0',x='composto',hue='ativo_moa')

# %%
display(composto_principal) #pega os 5 compostos que mais aparecem e mostra em texto separado detalhadamente
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# # Machine learning

# %%
from sklearn.linear_model import LogisticRegression #realiza a importação do pacote de machine learning
from sklearn.model_selection import train_test_split #realiza o import da separação de dados a ser analisado

x = dados_combinados.select_dtypes('float64') #criação da variável x de pesquisa
y = dados_combinados['ativo_moa'] #criação da variável y de pesquisa
x_treino , x_teste,y_treino , y_teste =train_test_split(x,y,test_size = 0.2,stratify=y,random_state = 376) #adicionando o random_state retira a chance de ficar mudando os valores a cada pesquisa realizada

modelo_rlogistica = LogisticRegression(max_iter=1000) #criação da variável que vai receber o método
modelo_rlogistica.fit(x,y) #chamado da função passando x e y acima
modelo_rlogistica.score(x_teste,y_teste) * 100 #calcula quantas predições deram certas e mostra a porcentagem
# Out:
# 66.99559101406678

# %% [markdown]
# ###levando para o código principal

# %%
from sklearn.model_selection import train_test_split 
x_treino , x_teste,y_treino , y_teste = train_test_split(x,y) #realiza a separação de dados que serão analisados para teste e para resposta

# %%
from sklearn.dummy import DummyClassifier #import de divisão dos valores detalhadamente
from sklearn.metrics import accuracy_score #import para calcular a acuracidade

modelo_dummy = DummyClassifier('most_frequent') #mostra os valores que aparecem com mais frequencia
modelo_dummy.fit(x_treino,y_treino)
previsao_dummy = modelo_dummy.predict(x_teste) #realiza a predição
accuracy_score(y_teste,previsao_dummy) #realiza o calculo da acuracidade
# Out:
# 0.6148807524353376

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %% [markdown]
# #Utilizando o sklearn.tree

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64') 
y = dados_combinados['ativo_moa'] 
x_treino , x_teste,y_treino , y_teste =train_test_split(x,y,test_size = 0.2,stratify=y,random_state = 376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3) #quantos niveis vai ter a arvore
modelo_arvore.fit(x_treino,y_treino)
modelo_arvore.score(x_teste,y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree

fig,ax = plt.subplots(figsize=(15,10), facecolor='k') #criando o background do grafico
tree.plot_tree(modelo_arvore, #parâmetro do plot_tree para fazer a busca
               ax=ax, #figura a ser criada
               fontsize=10, #tamanho da fonte
               rounded=True, #deixa arredondado os quadrados do gráfico
               filled=True, #deixa os gráficos coloridos
               feature_names= x_treino.columns, #nome das features
               class_names=['Não Ativado','Ativado']) #nome das classes dos mecanismos de ação
plt.show() #mostra o gráfico

# %% [markdown]
# #Utilizando dummies

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64') 
y = dados_combinados['ativo_moa'] 
x_treino , x_teste,y_treino , y_teste =train_test_split(x,y,test_size = 0.2,stratify=y,random_state = 376)

teste=[]
treino=[]

for i in range(1,15): #estrutura de repetição 
  modelo_arvore = DecisionTreeClassifier(max_depth = i) #quantos niveis vai ter a arvore
  modelo_arvore.fit(x_treino,y_treino)
  teste.append(modelo_arvore.score(x_teste,y_teste))  #calcula o quanto está acertando o teste
  treino.append(modelo_arvore.score(x_treino,y_treino)) #calcula o quanto está acertando o treino

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6199874028973336,
#  0.6206172580306529,
#  0.6187276926306949,
#  0.6216670165861852,
#  0.6214570648750787,
#  0.6164182238085241,
#  0.6111694310308629,
#  0.6122191895863951,
#  0.598992231786689,
#  0.5977325215200504,
#  0.6000419903422213]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7068395359823632,
#  0.7293055482651829,
#  0.752926355571886,
#  0.7770195790247231,
#  0.799223137893024]

# %% [markdown]
# #Utilizando lineplot

# %%
sns.lineplot(x = range(1,15),y=teste,label='teste')
sns.lineplot(x = range(1,15),y=treino,label='teste')

# %%
pd.get_dummies(dados_combinados,columns=['tratamento','dose','tempo']) #muda a coluna do formato String para numeros para facilitar a realização de codigos
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
dados_combinados.drop(['id','n_moa','ativo_moa','composto'],axis = 1) #retira esses elementos da pesquisa
# Out:
#          tratamento  tempo dose     g-0  ...    c-96    c-97    c-98    c-99
# 0         com_droga     24   D1  1.0620  ... -0.3981  0.2139  0.3801  0.4176
# 1         com_droga     72   D1  0.0743  ...  0.1522  0.1241  0.6077  0.7371
# 2         com_droga     48   D1  0.6280  ... -0.6417 -0.2187 -1.4080  0.6931
# 3         com_droga     48   D1 -0.5138  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4         com_droga     72   D2 -0.3254  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...    ...  ...     ...  ...     ...     ...     ...     ...
# 23809     com_droga     24   D2  0.1394  ...  0.0631  0.9171  0.5258  0.4680
# 23810     com_droga     24   D2 -1.3260  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  com_controle     48   D2  0.3942  ...  0.2256  0.7592  0.6656  0.3808
# 23812     com_droga     24   D1  0.6660  ...  0.1732  0.7015 -0.6290  0.0740
# 23813     com_droga     72   D1 -0.8598  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 875 columns]

# %% [markdown]
# #Utilizando sklearn.ensemble

# %%
from sklearn.ensemble import RandomForestClassifier #cria diversos conjuntos para realizar a classificação

x = dados_combinados.drop(['id','n_moa','ativo_moa','composto'],axis = 1)
x = pd.get_dummies(x,columns=['tratamento','dose','tempo'])
y = dados_combinados['ativo_moa'] 
x_treino , x_teste,y_treino , y_teste =train_test_split(x,y,test_size = 0.2,stratify=y,random_state = 376)

modelo_randomforest = RandomForestClassifier() #quantos niveis vai ter a arvore
modelo_randomforest.fit(x_treino,y_treino)
modelo_randomforest.score(x_teste,y_teste)
# Out:
# 0.6836027713625866

# %% [markdown]
# #Desafio 01 - Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y,test_size = 0.2,stratify=y,random_state=376)

modelo_KNeighborsClassifier = KNeighborsClassifier(n_neighbors=3)
modelo_KNeighborsClassifier.fit(x_treino,y_treino)
modelo_KNeighborsClassifier.score(x_teste,y_teste)
# Out:
# 0.6115893344530758

# %% [markdown]
# #Desafio 02 - Estude a documentação do Sklearn

# %% [markdown]
# Estudar a documentação do sklearn - Checked

# %% [markdown]
# #Desafio 03 - Matriz de correlação para tentar eliminar variáveis que, muito próximas de -1 ou 1

# %%
cor_matrix = dados_combinados.drop(['tempo','n_moa','ativo_moa'],axis=1).corr().abs()
cor_matrix.head()
# Out:
#           g-0       g-1       g-2  ...      c-97      c-98      c-99
# g-0  1.000000  0.086032  0.176188  ...  0.622840  0.640484  0.609238
# g-1  0.086032  1.000000  0.054518  ...  0.008487  0.002824  0.002308
# g-2  0.176188  0.054518  1.000000  ...  0.178812  0.170152  0.172124
# g-3  0.011266  0.027855  0.042633  ...  0.049951  0.079855  0.037579
# g-4  0.403153  0.193647  0.013968  ...  0.394904  0.366693  0.390581
#
# [5 rows x 872 columns]

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
print(upper_tri)
# Out:
#       g-0       g-1       g-2       g-3  ...      c-96      c-97      c-98      c-99
# g-0   NaN  0.086032  0.176188  0.011266  ...  0.646784  0.622840  0.640484  0.609238
# g-1   NaN       NaN  0.054518  0.027855  ...  0.022127  0.008487  0.002824  0.002308
# g-2   NaN       NaN       NaN  0.042633  ...  0.182540  0.178812  0.170152  0.172124
# g-3   NaN       NaN       NaN       NaN  ...  0.083846  0.049951  0.079855  0.037579
# g-4   NaN       NaN       NaN       NaN  ...  0.379085  0.394904  0.366693  0.390581
# ...   ...       ...       ...       ...  ...       ...       ...       ...       ...
# c-95  NaN       NaN       NaN       NaN  ...  0.821950  0.811155  0.787529  0.758110
# c-96  NaN       NaN       NaN       NaN  ...       NaN  0.863061  0.819600  0.789649
# c-97  NaN       NaN       NaN       NaN  ...       NaN       NaN  0.801809  0.775300
# c-98  NaN       NaN       NaN       NaN  ...       NaN       NaN       NaN  0.755991
# ...

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.85)]
print(to_drop)
# Out:
# ['g-50', 'c-2', 'c-4', 'c-5', 'c-6', 'c-8', 'c-10', 'c-11', 'c-12', 'c-13', 'c-14', 'c-15', 'c-17', 'c-18', 'c-20', 'c-21', 'c-23', 'c-24', 'c-25', 'c-26', 'c-27', 'c-28', 'c-30', 'c-31', 'c-32', 'c-33', 'c-34', 'c-35', 'c-36', 'c-38', 'c-39', 'c-40', 'c-41', 'c-42', 'c-43', 'c-44', 'c-45', 'c-46', 'c-47', 'c-48', 'c-49', 'c-50', 'c-51', 'c-52', 'c-53', 'c-54', 'c-55', 'c-57', 'c-59', 'c-60', 'c-61', 'c-62', 'c-63', 'c-64', 'c-65', 'c-66', 'c-67', 'c-68', 'c-70', 'c-71', 'c-72', 'c-73', 'c-75', 'c-76', 'c-77', 'c-78', 'c-79', 'c-80', 'c-81', 'c-82', 'c-83', 'c-84', 'c-85', 'c-88', 'c-89', 'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-96', 'c-97', 'c-98']

# %%
len(to_drop)
# Out:
# 83

# %%
dataset = dados_combinados.drop(['id','tratamento','dose','composto','tempo'],axis=1)

# %%
dataset['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dataset['ativo_moa'] = (dataset['n_moa'] != 0)

# %%
dataset.head()
# Out:
#       g-0     g-1     g-2     g-3  ...    c-98    c-99  n_moa  ativo_moa
# 0  1.0620  0.5577 -0.2479 -0.6208  ...  0.3801  0.4176    3.0       True
# 1  0.0743  0.4087  0.2991  0.0604  ...  0.6077  0.7371    0.0      False
# 2  0.6280  0.5817  1.5540 -0.0764  ... -1.4080  0.6931    7.0       True
# 3 -0.5138 -0.2491 -0.2656  0.5288  ... -0.3876 -0.8154    0.0      False
# 4 -0.3254 -0.4009  0.9700  0.6919  ... -0.3786  0.7125    3.0       True
#
# [5 rows x 874 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dataset.select_dtypes('float64')
y = dataset['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 1.0

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1).head();

# %%
pd.get_dummies(dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1), columns=['tratamento', 'dose', 'tempo']).head();

# %% [markdown]
# #Desafio 04 - Teste outras perguntas (problemas). 0,1 ou +

# %%
dados_combinados = dados_combinados.copy()
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
df1 = dados_combinados[(dados_combinados['n_moa'] == 0) | (dados_combinados['n_moa'] == 2)].copy()
df1.head()
# Out:
#               id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 1   id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 3   id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 6   id_001bd861f  com_droga     24   D2  ...  0.1351 -0.3179      0      False
# 8   id_00224bf20  com_droga     48   D1  ... -0.6420  0.5543      0      False
# 11  id_0024bcd70  com_droga     48   D2  ...  0.8285  0.3605      2       True
#
# [5 rows x 879 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

x = df1.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = df1['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier(n_estimators = 200)
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9238997555012225

# %%
dados_combinados['n_moa'].max()
# Out:
# 7

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

for i in range(1, dados_combinados['n_moa'].max()+1):
  df1 = dados_combinados[(dados_combinados['n_moa'] == 0) | (dados_combinados['n_moa'] == i)].copy()
  x = df1.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
  x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
  y = df1['ativo_moa'] 
  x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3, stratify=y, random_state=376)

  modelo_randomforest = RandomForestClassifier(n_estimators = 200)
  modelo_randomforest.fit(x_treino, y_treino)
  print(f'Acurácia do modelo para o par (0, {i}): {modelo_randomforest.score(x_teste, y_teste)}')
# Out:
# Acurácia do modelo para o par (0, 1): 0.6604261796042618
# Acurácia do modelo para o par (0, 2): 0.9245110024449877
# Acurácia do modelo para o par (0, 3): 0.9703550499827646
# Acurácia do modelo para o par (0, 4): 0.9939865581888928
# Acurácia do modelo para o par (0, 5): 0.9985785358919688
# Acurácia do modelo para o par (0, 6): 1.0
# Acurácia do modelo para o par (0, 7): 0.9992887624466572

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

for i in range(1, dados_combinados['n_moa'].max()+1):
  df1 = dados_combinados[(dados_combinados['n_moa'] == 0) | (dados_combinados['n_moa'] == i)].copy()

  x = df1.select_dtypes('float64')
  y = df1['ativo_moa']
  x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3)

  modelo_dummy = DummyClassifier('most_frequent')
  modelo_dummy.fit(x_treino, y_treino)
  previsao_dummy = modelo_dummy.predict(x_teste)
  print(f'Acurácia do modelo para o par (0, {i}): {accuracy_score(y_teste, previsao_dummy)}')
# Out:
# Acurácia do modelo para o par (0, 1): 0.5668188736681887
# Acurácia do modelo para o par (0, 2): 0.8496332518337408
# Acurácia do modelo para o par (0, 3): 0.9710444674250258
# Acurácia do modelo para o par (0, 4): 0.9943402900601345
# Acurácia do modelo para o par (0, 5): 0.9985785358919688
# Acurácia do modelo para o par (0, 6): 1.0
# Acurácia do modelo para o par (0, 7): 0.9996443812233285

# %%
df1 = dados_combinados[(dados_combinados['n_moa'] != 1)].copy()
df1.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 6  id_001bd861f  com_droga     24   D2  ...  0.1351 -0.3179      0      False
# 8  id_00224bf20  com_droga     48   D1  ... -0.6420  0.5543      0      False
#
# [5 rows x 879 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

x = df1.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = df1['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier(n_estimators = 200)
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9063515509601182

# %% [markdown]
# #Desafio 05 - Escolha a droga mais utilizada e tente criar um modelo para prever está label.

# %%
dados_combinados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# f2cc15da6       1
# e6b7b845f       1
# 2b06f0b4b       1
# 547f80a41       1
# 153840764       1
# Name: composto, Length: 3289, dtype: int64

# %%
dt = dados_combinados.query('composto in ["9f80f3f77", "8b87a7a83"]')

# %%
x = dt.loc[:,'g-0':'g-10'] 
y = dt['composto'].map({'9f80f3f77': 0, '8b87a7a83': 1})
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y,random_state=376)

# %%
modelo_rlogistica = LogisticRegression()
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.9444444444444444

# %% [markdown]
# #Desafio 06 - Resumo do que você aprendeu

# %% [markdown]
# Como constatado nos desafios anteriores, o que se pôde perceber pelos números do estudo é que os compostos que ativam apenas 1 mecanismo "puxam para baixo" a acurácia do nosso modelo. Se o nosso objetivo é treinar o modelo para prever bem se um composto (input) vai ou não ter ativação de algum mecanisco qualquer (output), o ideal seria removê-los da nossa análise para não subaproveitarmos os nosso resultados.
